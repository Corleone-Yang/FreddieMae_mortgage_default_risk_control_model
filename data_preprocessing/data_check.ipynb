# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_08 = "/content/drive/Shareddrives/Article/data_clean/MPDF08.csv"
file_20 = "/content/drive/Shareddrives/Article/data_clean/MPDF20.csv"
file_22 = "/content/drive/Shareddrives/Article/data_clean/MPDF22.csv"

df_08 = pd.read_csv(file_08)
df_20 = pd.read_csv(file_20)
df_22 = pd.read_csv(file_22)
# Out:
# <ipython-input-6-7cd0b640e17d>:7: DtypeWarning: Columns (3,7,23,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_08 = pd.read_csv(file_08)
# <ipython-input-6-7cd0b640e17d>:8: DtypeWarning: Columns (7,23,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_20 = pd.read_csv(file_20)
# <ipython-input-6-7cd0b640e17d>:9: DtypeWarning: Columns (7,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_22 = pd.read_csv(file_22)

# %%
df_08.head()
# Out:
#              Id     MRP      CAU CLDS  LA  RM2LM  DSD   MF  ZBC  ZBED  ...  \
# 0  F08Q10000071  200802  58000.0    0   0    360  NaN  NaN  NaN   NaN  ...
# 1  F08Q10000071  200803  58000.0    0   1    359  NaN  NaN  NaN   NaN  ...
# 2  F08Q10000071  200804  58000.0    0   2    358  NaN  NaN  NaN   NaN  ...
# 3  F08Q10000071  200805  57000.0    0   3    357  NaN  NaN  NaN   NaN  ...
# 4  F08Q10000071  200806  57000.0    0   4    356  NaN  NaN  NaN   NaN  ...
#
#    MC  SMF  DPP  ELTV  ZBRU  DAI  DDTD  BASC  CMMC      IBU
# 0 NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN  58000.0
# 1 NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN  58000.0
# 2 NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN  58000.0
# 3 NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN  57000.0
# 4 NaN  NaN  NaN   NaN   NaN  NaN   NaN   NaN   NaN  57000.0
#
# [5 rows x 32 columns]

# %%
df_filter = df_08[['CLDS', 'ALC', 'DSD']]
df_filter.head()
# Out:
#   CLDS  ALC  DSD
# 0    0  NaN  NaN
# 1    0  NaN  NaN
# 2    0  NaN  NaN
# 3    0  NaN  NaN
# 4    0  NaN  NaN

# %%
# Calculate the counts for each specific value in CLDS column
clds_counts = df_08['CLDS'].value_counts(dropna=False)
clds_equal_0_count = clds_counts.get(0, 0)
clds_equal_1_count = clds_counts.get(1, 0)
clds_equal_2_count = clds_counts.get(2, 0)
clds_equal_3_count = clds_counts.get(3, 0)
clds_equal_4_count = clds_counts.get(4, 0)
clds_equal_RA_count = clds_counts.get('RA', 0)

# Print the counts
print(f"Count of CLDS == 0: {clds_equal_0_count}")
print(f"Count of CLDS == 1: {clds_equal_1_count}")
print(f"Count of CLDS == 2: {clds_equal_2_count}")
print(f"Count of CLDS == 3: {clds_equal_3_count}")
print(f"Count of CLDS == 4: {clds_equal_4_count}")
print(f"Count of CLDS == RA: {clds_equal_RA_count}")
# Out:
# Count of CLDS == 0: 31909
# Count of CLDS == 1: 505
# Count of CLDS == 2: 117
# Count of CLDS == 3: 45
# Count of CLDS == 4: 30
# Count of CLDS == RA: 10476
# Count of CLDS == blank: 0

# %%
# Calculate the counts for each specific value in CLDS column
clds_counts = df_20['CLDS'].value_counts(dropna=False)
clds_equal_0_count = clds_counts.get(0, 0)
clds_equal_1_count = clds_counts.get(1, 0)
clds_equal_2_count = clds_counts.get(2, 0)
clds_equal_3_count = clds_counts.get(3, 0)
clds_equal_4_count = clds_counts.get(4, 0)
clds_equal_RA_count = clds_counts.get('RA', 0)

# Print the counts
print(f"Count of CLDS == 0: {clds_equal_0_count}")
print(f"Count of CLDS == 1: {clds_equal_1_count}")
print(f"Count of CLDS == 2: {clds_equal_2_count}")
print(f"Count of CLDS == 3: {clds_equal_3_count}")
print(f"Count of CLDS == 4: {clds_equal_4_count}")
print(f"Count of CLDS == RA: {clds_equal_RA_count}")
# Out:
# Count of CLDS == 0: 1319204
# Count of CLDS == 1: 5945
# Count of CLDS == 2: 1575
# Count of CLDS == 3: 1000
# Count of CLDS == 4: 719
# Count of CLDS == RA: 0
